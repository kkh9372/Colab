# %% [markdown]
# <a href="https://colab.research.google.com/github/kkh9372/Colab/blob/main/Ch2.%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%EC%8B%A4%EC%8A%B5/9_%EA%B2%B0%EC%A0%95%ED%8A%B8%EB%A6%AC_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2021/10/20
이름 : 김관후 
내용 : 결정트리 실습하기
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree, metrics
import pydotplus
from sklearn.model_selection import train_test_split

# %%
# 데이터 불러오기
df_iris = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/file/iris.csv')
df_iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# 학습데이터
iris_train_data = df_iris.iloc[:, 0:4]
iris_train_label = df_iris.iloc[:, 4]
iris_train_label

train_data, test_data, train_label, test_label = train_test_split(iris_train_data, iris_train_label)
train_data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 86            6.7          3.1           4.7          1.5
# 102           7.1          3.0           5.9          2.1
# 35            5.0          3.2           1.2          0.2
# 125           7.2          3.2           6.0          1.8
# 90            5.5          2.6           4.4          1.2
# ..            ...          ...           ...          ...
# 85            6.0          3.4           4.5          1.6
# 71            6.1          2.8           4.0          1.3
# 79            5.7          2.6           3.5          1.0
# 18            5.7          3.8           1.7          0.3
# 36            5.5          3.5           1.3          0.2
#
# [112 rows x 4 columns]

# %%
# 학습하기
model = tree.DecisionTreeClassifier()
model.fit(train_data, train_label)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# 학습하기
model = tree.DecisionTreeClassifier()
model.fit(train_data, train_label)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# 테스트하기
result = model.predict(test_data)

# %%
# 성능평가
score = metrics.accuracy_score(result, test_label)
score
# Out:
# 0.9736842105263158

# %%
# 모델 시각화
fig = plt.figure(figsize=(12, 12))
tree.plot_tree(model, feature_names=['sepal.length',	'sepal.width',	'petal.length',	'petal.width'],
               class_names=['Setosa', 'Viricolor', 'Virginica'],
               filled=True)
# Out:
# [Text(206.03076923076924, 597.96, 'petal.width <= 0.7\ngini = 0.665\nsamples = 112\nvalue = [40, 38, 34]\nclass = Setosa'),
#  Text(154.52307692307693, 489.24, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]\nclass = Setosa'),
#  Text(257.53846153846155, 489.24, 'petal.length <= 4.75\ngini = 0.498\nsamples = 72\nvalue = [0, 38, 34]\nclass = Viricolor'),
#  Text(103.01538461538462, 380.52000000000004, 'petal.width <= 1.65\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]\nclass = Viricolor'),
#  Text(51.50769230769231, 271.8, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]\nclass = Viricolor'),
#  Text(154.52307692307693, 271.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Virginica'),
#  Text(412.0615384615385, 380.52000000000004, 'petal.width <= 1.75\ngini = 0.193\nsamples = 37\nvalue = [0, 4, 33]\nclass = Virginica'),
#  Text(257.53846153846155, 271.8, 'petal.length <= 5.05\ngini = 0.5\nsamples = 6\nvalue = [0, 3, 3]\nclass = Viricolor'),
# ...
